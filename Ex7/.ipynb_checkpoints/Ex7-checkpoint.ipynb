# %% [markdown]
# # Ex7. Segmentation map으로 도로 이미지 만들기
# ----------------------------------
# ## (1) 데이터 준비하기

# %%
import numpy
import tensorflow
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation
from tensorflow.keras import layers, Input, Model
from tensorflow.keras import losses
from tensorflow.keras import optimizers

print ('fin')
# Out:
# fin

# %%
#이미지 개수 확인
import os

data_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
#이미지 크기 확인
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
#이미지 나누기
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    original = img[:, w:, :] 
    original = tf.cast(original, tf.float32)
    return normalize(sketch), normalize(original)

f = data_path + os.listdir(data_path)[1]
sketch, original = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(original))

# %% [markdown]
# ### apply augmentation 방법을 적용

# %%
@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]   

print("fin")
# Out:
# fin

# %%
#시각화
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_original = apply_augmentation(sketch, original)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_original)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
#적용 확인 시각화
from tensorflow import data

def get_train(img_path):
    sketch, original = load_img(img_path)
    sketch, original = apply_augmentation(sketch, original)
    return sketch, original

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, original = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(original[0].astype(np.uint8))

# %% [markdown]
# --------------------------------------------
# ## (2) Generator 구성
#
# ### U-Net Generator 사용

# %%
#Encoder 및 Decoder에 사용되는 기본적인 블록
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)
    
print("fin")
# Out:
# fin

# %%
#정의된 블록들을 이용해 한 번에 U-Net Generator를 정의
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("fin")
# Out:
# fin

# %%
#U-Net 구조 Generator 내부의 각 출력이 적절한지 확인
UNetGenerator().get_summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block_64 (EncodeBlock)   (None, 128, 128, 64) 3072        input_9[0][0]
# __________________________________________________________________________________________________
# encode_block_65 (EncodeBlock)   (None, 64, 64, 128)  131584      encode_block_64[0][0]
# __________________________________________________________________________________________________
# encode_block_66 (EncodeBlock)   (None, 32, 32, 256)  525312      encode_block_65[0][0]
# __________________________________________________________________________________________________
# encode_block_67 (EncodeBlock)   (None, 16, 16, 512)  2099200     encode_block_66[0][0]
# __________________________________________________________________________________________________
# encode_block_68 (EncodeBlock)   (None, 8, 8, 512)    4196352     encode_block_67[0][0]
# __________________________________________________________________________________________________
# encode_block_69 (EncodeBlock)   (None, 4, 4, 512)    4196352     encode_block_68[0][0]
# __________________________________________________________________________________________________
# encode_block_70 (EncodeBlock)   (None, 2, 2, 512)    4196352     encode_block_69[0][0]
# __________________________________________________________________________________________________
# encode_block_71 (EncodeBlock)   (None, 1, 1, 512)    4196352     encode_block_70[0][0]
# __________________________________________________________________________________________________
# decode_block_56 (DecodeBlock)   (None, 2, 2, 512)    4196352     encode_block_71[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 2, 2, 1024)   0           decode_block_56[0][0]
#                                                                  encode_block_70[0][0]
# __________________________________________________________________________________________________
# decode_block_57 (DecodeBlock)   (None, 4, 4, 512)    8390656     concatenate_38[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 4, 4, 1024)   0           decode_block_57[0][0]
#                                                                  encode_block_69[0][0]
# __________________________________________________________________________________________________
# decode_block_58 (DecodeBlock)   (None, 8, 8, 512)    8390656     concatenate_39[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 8, 8, 1024)   0           decode_block_58[0][0]
#                                                                  encode_block_68[0][0]
# __________________________________________________________________________________________________
# decode_block_59 (DecodeBlock)   (None, 16, 16, 512)  8390656     concatenate_40[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 16, 16, 1024) 0           decode_block_59[0][0]
#                                                                  encode_block_67[0][0]
# __________________________________________________________________________________________________
# decode_block_60 (DecodeBlock)   (None, 32, 32, 256)  4195328     concatenate_41[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 32, 32, 512)  0           decode_block_60[0][0]
#                                                                  encode_block_66[0][0]
# __________________________________________________________________________________________________
# decode_block_61 (DecodeBlock)   (None, 64, 64, 128)  1049088     concatenate_42[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 64, 64, 256)  0           decode_block_61[0][0]
#                                                                  encode_block_65[0][0]
# __________________________________________________________________________________________________
# decode_block_62 (DecodeBlock)   (None, 128, 128, 64) 262400      concatenate_43[0][0]
# __________________________________________________________________________________________________
# concatenate_44 (Concatenate)    (None, 128, 128, 128 0           decode_block_62[0][0]
#                                                                  encode_block_64[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_71 (Conv2DTran (None, 256, 256, 3)  6144        concatenate_44[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# --------------------------
# ## (3) Discriminator 구성

# %%
#Discriminator 기본적인 블록 구현
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x 

print("fin")
# Out:
# fin

# %%
#출력 크기 확인
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d_22 (ZeroPaddi (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_124 (Conv2D)          (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_167 (Bat (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_114 (LeakyReLU)  (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
print("fin")
# Out:
# fin

# %%
#블록별 출력 크기 확인
Discriminator().get_summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_45 (Concatenate)    (None, 256, 256, 6)  0           input_11[0][0]
#                                                                  input_12[0][0]
# __________________________________________________________________________________________________
# disc_block_50 (DiscBlock)       (None, 128, 128, 64) 6144        concatenate_45[0][0]
# __________________________________________________________________________________________________
# disc_block_51 (DiscBlock)       (None, 64, 64, 128)  131584      disc_block_50[0][0]
# __________________________________________________________________________________________________
# disc_block_52 (DiscBlock)       (None, 32, 32, 256)  525312      disc_block_51[0][0]
# __________________________________________________________________________________________________
# disc_block_53 (DiscBlock)       (None, 31, 31, 512)  2099200     disc_block_52[0][0]
# __________________________________________________________________________________________________
# disc_block_54 (DiscBlock)       (None, 30, 30, 1)    8192        disc_block_53[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 30, 30, 1)    0           disc_block_54[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
#출력 시각화
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# ## (4) 학습 및 테스트

# %%
#손실함수 : Generator 및 Discriminator의 손실 계산 정의
bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

print("fin")
# Out:
# fin

# %%
#최적화 : 사용할 optimizer 설정
gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

print("fin")
# Out:
# fin

# %%
#가중치 업데이트
@tf.function
def train_step(sketch, original):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, original, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, original, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

print("fin")
# Out:
# fin

# %%
#학습
EPOCHS = 30

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, original) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, original)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 20 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[20]
# Generator_loss:0.9148
# L1_loss:0.3558
# Discriminator_loss:1.1589
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.2507
# L1_loss:0.2317
# Discriminator_loss:0.8944
#
# EPOCH[1] - STEP[60]
# Generator_loss:0.9975
# L1_loss:0.2380
# Discriminator_loss:1.2122
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.4840
# L1_loss:0.2687
# Discriminator_loss:0.9166
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.7595
# L1_loss:0.2140
# Discriminator_loss:0.7196
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.9798
# L1_loss:0.2493
# Discriminator_loss:0.9335
#
# EPOCH[1] - STEP[140]
# Generator_loss:1.5983
# L1_loss:0.2966
# Discriminator_loss:1.1288
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.3394
# L1_loss:0.2285
# Discriminator_loss:0.4886
#
# EPOCH[1] - STEP[180]
# Generator_loss:1.9111
# L1_loss:0.1926
# Discriminator_loss:0.8531
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.3274
# L1_loss:0.1962
# Discriminator_loss:0.6989
#
# EPOCH[1] - STEP[220]
# Generator_loss:2.5615
# L1_loss:0.2201
# Discriminator_loss:0.5760
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.2042
# L1_loss:0.2312
# Discriminator_loss:0.7188
#
# EPOCH[2] - STEP[20]
# Generator_loss:1.5661
# L1_loss:0.1966
# Discriminator_loss:1.4494
#
# EPOCH[2] - STEP[40]
# Generator_loss:1.5213
# L1_loss:0.2397
# Discriminator_loss:0.6607
#
# EPOCH[2] - STEP[60]
# Generator_loss:1.5075
# L1_loss:0.2242
# Discriminator_loss:0.5301
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.8262
# L1_loss:0.2278
# Discriminator_loss:0.9478
#
# EPOCH[2] - STEP[100]
# Generator_loss:2.9694
# L1_loss:0.2128
# Discriminator_loss:0.6759
#
# EPOCH[2] - STEP[120]
# Generator_loss:2.8473
# L1_loss:0.1899
# Discriminator_loss:0.7053
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.8084
# L1_loss:0.2127
# Discriminator_loss:0.8967
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.5744
# L1_loss:0.2071
# Discriminator_loss:0.5462
#
# EPOCH[2] - STEP[180]
# Generator_loss:3.3049
# L1_loss:0.1977
# Discriminator_loss:1.6818
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.9453
# L1_loss:0.1866
# Discriminator_loss:0.4112
#
# EPOCH[2] - STEP[220]
# Generator_loss:1.7482
# L1_loss:0.1956
# Discriminator_loss:0.5366
#
# EPOCH[2] - STEP[240]
# Generator_loss:1.9777
# L1_loss:0.2115
# Discriminator_loss:0.7048
#
# EPOCH[3] - STEP[20]
# Generator_loss:0.8766
# L1_loss:0.1984
# Discriminator_loss:1.4721
#
# EPOCH[3] - STEP[40]
# Generator_loss:1.7382
# L1_loss:0.1856
# Discriminator_loss:0.3952
#
# EPOCH[3] - STEP[60]
# Generator_loss:2.2143
# L1_loss:0.2317
# Discriminator_loss:0.4633
#
# EPOCH[3] - STEP[80]
# Generator_loss:1.0512
# L1_loss:0.2719
# Discriminator_loss:0.6612
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.8624
# L1_loss:0.2306
# Discriminator_loss:0.5202
#
# EPOCH[3] - STEP[120]
# Generator_loss:1.7260
# L1_loss:0.1698
# Discriminator_loss:0.8608
#
# EPOCH[3] - STEP[140]
# Generator_loss:0.8855
# L1_loss:0.1976
# Discriminator_loss:0.8553
#
# EPOCH[3] - STEP[160]
# Generator_loss:1.2885
# L1_loss:0.2638
# Discriminator_loss:0.4994
#
# EPOCH[3] - STEP[180]
# Generator_loss:0.6815
# L1_loss:0.1846
# Discriminator_loss:0.8814
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.6828
# L1_loss:0.2528
# Discriminator_loss:0.4105
#
# EPOCH[3] - STEP[220]
# Generator_loss:2.4489
# L1_loss:0.2064
# Discriminator_loss:0.7125
#
# EPOCH[3] - STEP[240]
# Generator_loss:1.7686
# L1_loss:0.1851
# Discriminator_loss:0.6595
#
# EPOCH[4] - STEP[20]
# Generator_loss:2.4516
# L1_loss:0.2180
# Discriminator_loss:0.2826
#
# EPOCH[4] - STEP[40]
# Generator_loss:2.0553
# L1_loss:0.2424
# Discriminator_loss:0.4873
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.9717
# L1_loss:0.1983
# Discriminator_loss:0.4550
#
# EPOCH[4] - STEP[80]
# Generator_loss:1.1386
# L1_loss:0.2277
# Discriminator_loss:0.6119
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.2848
# L1_loss:0.1639
# Discriminator_loss:1.4258
#
# EPOCH[4] - STEP[120]
# Generator_loss:0.5825
# L1_loss:0.1984
# Discriminator_loss:1.1315
#
# EPOCH[4] - STEP[140]
# Generator_loss:1.8305
# L1_loss:0.1754
# Discriminator_loss:1.0391
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.8578
# L1_loss:0.2027
# Discriminator_loss:0.6438
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.5020
# L1_loss:0.2140
# Discriminator_loss:0.7506
#
# EPOCH[4] - STEP[200]
# Generator_loss:2.3260
# L1_loss:0.2338
# Discriminator_loss:0.3150
#
# EPOCH[4] - STEP[220]
# Generator_loss:0.5110
# L1_loss:0.2078
# Discriminator_loss:1.1973
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.0730
# L1_loss:0.1832
# Discriminator_loss:0.7814
#
# EPOCH[5] - STEP[20]
# Generator_loss:1.8734
# L1_loss:0.1803
# Discriminator_loss:0.7061
#
# EPOCH[5] - STEP[40]
# Generator_loss:2.3200
# L1_loss:0.1943
# Discriminator_loss:1.2246
#
# EPOCH[5] - STEP[60]
# Generator_loss:2.5314
# L1_loss:0.1935
# Discriminator_loss:0.6117
#
# EPOCH[5] - STEP[80]
# Generator_loss:2.2942
# L1_loss:0.2103
# Discriminator_loss:0.5587
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.8644
# L1_loss:0.2190
# Discriminator_loss:0.3401
#
# EPOCH[5] - STEP[120]
# Generator_loss:2.5039
# L1_loss:0.1911
# Discriminator_loss:0.6974
#
# EPOCH[5] - STEP[140]
# Generator_loss:1.9223
# L1_loss:0.1934
# Discriminator_loss:0.6461
#
# EPOCH[5] - STEP[160]
# Generator_loss:0.9135
# L1_loss:0.2571
# Discriminator_loss:0.7001
# EPOCH[5] - STEP[180]
# Generator_loss:2.7942
# L1_loss:0.1889
# Discriminator_loss:0.5450
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.9886
# L1_loss:0.1820
# Discriminator_loss:0.3712
#
# EPOCH[5] - STEP[220]
# Generator_loss:1.6366
# L1_loss:0.2122
# Discriminator_loss:0.7367
#
# EPOCH[5] - STEP[240]
# Generator_loss:2.5411
# L1_loss:0.2000
# Discriminator_loss:0.4725
#
# EPOCH[6] - STEP[20]
# Generator_loss:1.2396
# L1_loss:0.1695
# Discriminator_loss:1.1964
#
# EPOCH[6] - STEP[40]
# Generator_loss:3.4032
# L1_loss:0.2018
# Discriminator_loss:1.3249
#
# EPOCH[6] - STEP[60]
# Generator_loss:2.4015
# L1_loss:0.1648
# Discriminator_loss:0.5023
#
# EPOCH[6] - STEP[80]
# Generator_loss:1.0533
# L1_loss:0.1824
# Discriminator_loss:0.5583
#
# EPOCH[6] - STEP[100]
# Generator_loss:0.7733
# L1_loss:0.1544
# Discriminator_loss:1.0181
#
# EPOCH[6] - STEP[120]
# Generator_loss:1.8210
# L1_loss:0.1832
# Discriminator_loss:0.6478
#
# EPOCH[6] - STEP[140]
# Generator_loss:3.3056
# L1_loss:0.1585
# Discriminator_loss:1.1787
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.0372
# L1_loss:0.1871
# Discriminator_loss:0.7703
#
# EPOCH[6] - STEP[180]
# Generator_loss:0.6286
# L1_loss:0.1773
# Discriminator_loss:1.1267
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.6120
# L1_loss:0.1900
# Discriminator_loss:0.4932
#
# EPOCH[6] - STEP[220]
# Generator_loss:1.1833
# L1_loss:0.2100
# Discriminator_loss:0.6730
#
# EPOCH[6] - STEP[240]
# Generator_loss:2.0999
# L1_loss:0.2396
# Discriminator_loss:0.3174
#
# EPOCH[7] - STEP[20]
# Generator_loss:2.0544
# L1_loss:0.2087
# Discriminator_loss:0.4984
#
# EPOCH[7] - STEP[40]
# Generator_loss:1.9875
# L1_loss:0.1663
# Discriminator_loss:0.7623
#
# EPOCH[7] - STEP[60]
# Generator_loss:0.9344
# L1_loss:0.1869
# Discriminator_loss:0.7556
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.9190
# L1_loss:0.2006
# Discriminator_loss:0.5005
#
# EPOCH[7] - STEP[100]
# Generator_loss:2.0269
# L1_loss:0.2149
# Discriminator_loss:0.6076
#
# EPOCH[7] - STEP[120]
# Generator_loss:1.6499
# L1_loss:0.2207
# Discriminator_loss:0.9794
#
# EPOCH[7] - STEP[140]
# Generator_loss:2.1958
# L1_loss:0.1480
# Discriminator_loss:0.9375
#
# EPOCH[7] - STEP[160]
# Generator_loss:0.8996
# L1_loss:0.1831
# Discriminator_loss:1.0141
#
# EPOCH[7] - STEP[180]
# Generator_loss:2.0873
# L1_loss:0.2061
# Discriminator_loss:0.3607
#
# EPOCH[7] - STEP[200]
# Generator_loss:2.6852
# L1_loss:0.1701
# Discriminator_loss:0.8842
#
# EPOCH[7] - STEP[220]
# Generator_loss:1.3897
# L1_loss:0.1817
# Discriminator_loss:0.6661
#
# EPOCH[7] - STEP[240]
# Generator_loss:1.5328
# L1_loss:0.1743
# Discriminator_loss:0.4073
#
# EPOCH[8] - STEP[20]
# Generator_loss:1.2811
# L1_loss:0.2045
# Discriminator_loss:0.5579
#
# EPOCH[8] - STEP[40]
# Generator_loss:1.1506
# L1_loss:0.1968
# Discriminator_loss:0.5537
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.8663
# L1_loss:0.1765
# Discriminator_loss:0.3604
#
# EPOCH[8] - STEP[80]
# Generator_loss:0.9756
# L1_loss:0.1777
# Discriminator_loss:1.1260
#
# EPOCH[8] - STEP[100]
# Generator_loss:2.7928
# L1_loss:0.1808
# Discriminator_loss:1.0234
#
# EPOCH[8] - STEP[120]
# Generator_loss:2.6613
# L1_loss:0.1894
# Discriminator_loss:0.8498
#
# EPOCH[8] - STEP[140]
# Generator_loss:2.1215
# L1_loss:0.2072
# Discriminator_loss:0.4430
#
# EPOCH[8] - STEP[160]
# Generator_loss:0.1413
# L1_loss:0.2008
# Discriminator_loss:2.5298
#
# EPOCH[8] - STEP[180]
# Generator_loss:2.2593
# L1_loss:0.2088
# Discriminator_loss:0.3879
#
# EPOCH[8] - STEP[200]
# Generator_loss:2.5828
# L1_loss:0.1812
# Discriminator_loss:0.3655
#
# EPOCH[8] - STEP[220]
# Generator_loss:2.4743
# L1_loss:0.2118
# Discriminator_loss:0.2850
#
# EPOCH[8] - STEP[240]
# Generator_loss:1.8523
# L1_loss:0.1599
# Discriminator_loss:1.3466
#
# EPOCH[9] - STEP[20]
# Generator_loss:1.2018
# L1_loss:0.1328
# Discriminator_loss:1.0707
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.6697
# L1_loss:0.1542
# Discriminator_loss:0.8150
#
# EPOCH[9] - STEP[60]
# Generator_loss:0.7721
# L1_loss:0.1754
# Discriminator_loss:0.9777
#
# EPOCH[9] - STEP[80]
# Generator_loss:3.1643
# L1_loss:0.1573
# Discriminator_loss:0.5085
#
# EPOCH[9] - STEP[100]
# Generator_loss:1.8251
# L1_loss:0.1935
# Discriminator_loss:1.1537
#
# EPOCH[9] - STEP[120]
# Generator_loss:0.4108
# L1_loss:0.2075
# Discriminator_loss:1.3497
#
# EPOCH[9] - STEP[140]
# Generator_loss:1.9802
# L1_loss:0.1676
# Discriminator_loss:0.5999
#
# EPOCH[9] - STEP[160]
# Generator_loss:0.9226
# L1_loss:0.1725
# Discriminator_loss:1.1440
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.5879
# L1_loss:0.1559
# Discriminator_loss:1.2490
#
# EPOCH[9] - STEP[200]
# Generator_loss:0.9527
# L1_loss:0.1905
# Discriminator_loss:0.8200
#
# EPOCH[9] - STEP[220]
# Generator_loss:1.8640
# L1_loss:0.1636
# Discriminator_loss:0.4131
#
# EPOCH[9] - STEP[240]
# Generator_loss:0.5016
# L1_loss:0.2033
# Discriminator_loss:1.4099
#
# EPOCH[10] - STEP[20]
# Generator_loss:1.7120
# L1_loss:0.2165
# Discriminator_loss:0.3471
#
# EPOCH[10] - STEP[40]
# Generator_loss:1.4991
# L1_loss:0.1805
# Discriminator_loss:0.5435
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.4715
# L1_loss:0.1874
# Discriminator_loss:0.7528
#
# EPOCH[10] - STEP[80]
# Generator_loss:0.2353
# L1_loss:0.1835
# Discriminator_loss:1.7256
# EPOCH[10] - STEP[100]
# Generator_loss:2.6501
# L1_loss:0.1558
# Discriminator_loss:0.6989
#
# EPOCH[10] - STEP[120]
# Generator_loss:1.3453
# L1_loss:0.2470
# Discriminator_loss:0.6675
#
# EPOCH[10] - STEP[140]
# Generator_loss:2.2072
# L1_loss:0.1310
# Discriminator_loss:1.6041
#
# EPOCH[10] - STEP[160]
# Generator_loss:0.5539
# L1_loss:0.1960
# Discriminator_loss:0.9576
#
# EPOCH[10] - STEP[180]
# Generator_loss:3.3209
# L1_loss:0.1471
# Discriminator_loss:2.2756
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.0278
# L1_loss:0.1644
# Discriminator_loss:0.9314
#
# EPOCH[10] - STEP[220]
# Generator_loss:1.7402
# L1_loss:0.1627
# Discriminator_loss:0.5655
#
# EPOCH[10] - STEP[240]
# Generator_loss:0.8317
# L1_loss:0.1770
# Discriminator_loss:0.8469
#
# EPOCH[11] - STEP[20]
# Generator_loss:1.8400
# L1_loss:0.1641
# Discriminator_loss:0.4619
#
# EPOCH[11] - STEP[40]
# Generator_loss:2.7828
# L1_loss:0.1683
# Discriminator_loss:0.5451
#
# EPOCH[11] - STEP[60]
# Generator_loss:1.1839
# L1_loss:0.1558
# Discriminator_loss:0.5853
#
# EPOCH[11] - STEP[80]
# Generator_loss:2.3922
# L1_loss:0.1555
# Discriminator_loss:1.9670
#
# EPOCH[11] - STEP[100]
# Generator_loss:2.3312
# L1_loss:0.1952
# Discriminator_loss:0.4821
#
# EPOCH[11] - STEP[120]
# Generator_loss:1.8169
# L1_loss:0.1913
# Discriminator_loss:0.2851
#
# EPOCH[11] - STEP[140]
# Generator_loss:1.9395
# L1_loss:0.1601
# Discriminator_loss:0.3533
#
# EPOCH[11] - STEP[160]
# Generator_loss:1.6728
# L1_loss:0.1865
# Discriminator_loss:1.6015
#
# EPOCH[11] - STEP[180]
# Generator_loss:0.4576
# L1_loss:0.1759
# Discriminator_loss:1.3200
#
# EPOCH[11] - STEP[200]
# Generator_loss:1.9467
# L1_loss:0.1398
# Discriminator_loss:1.3861
#
# EPOCH[11] - STEP[220]
# Generator_loss:1.6749
# L1_loss:0.1940
# Discriminator_loss:0.4482
#
# EPOCH[11] - STEP[240]
# Generator_loss:3.1884
# L1_loss:0.1992
# Discriminator_loss:0.1985
#
# EPOCH[12] - STEP[20]
# Generator_loss:1.0811
# L1_loss:0.1416
# Discriminator_loss:0.8428
#
# EPOCH[12] - STEP[40]
# Generator_loss:2.1877
# L1_loss:0.2166
# Discriminator_loss:0.4949
#
# EPOCH[12] - STEP[60]
# Generator_loss:1.9608
# L1_loss:0.1883
# Discriminator_loss:0.4036
#
# EPOCH[12] - STEP[80]
# Generator_loss:0.5163
# L1_loss:0.1572
# Discriminator_loss:1.3276
#
# EPOCH[12] - STEP[100]
# Generator_loss:1.3524
# L1_loss:0.1567
# Discriminator_loss:0.5133
#
# EPOCH[12] - STEP[120]
# Generator_loss:1.3519
# L1_loss:0.1619
# Discriminator_loss:0.6383
#
# EPOCH[12] - STEP[140]
# Generator_loss:1.9131
# L1_loss:0.2046
# Discriminator_loss:0.3410
#
# EPOCH[12] - STEP[160]
# Generator_loss:1.7712
# L1_loss:0.1601
# Discriminator_loss:0.7826
#
# EPOCH[12] - STEP[180]
# Generator_loss:0.7455
# L1_loss:0.1601
# Discriminator_loss:0.8859
#
# EPOCH[12] - STEP[200]
# Generator_loss:3.9521
# L1_loss:0.1992
# Discriminator_loss:1.0009
#
# EPOCH[12] - STEP[220]
# Generator_loss:0.6539
# L1_loss:0.1704
# Discriminator_loss:0.9017
#
# EPOCH[12] - STEP[240]
# Generator_loss:2.2163
# L1_loss:0.1822
# Discriminator_loss:0.6495
#
# EPOCH[13] - STEP[20]
# Generator_loss:2.7628
# L1_loss:0.1699
# Discriminator_loss:0.5397
#
# EPOCH[13] - STEP[40]
# Generator_loss:1.0872
# L1_loss:0.2019
# Discriminator_loss:0.7487
#
# EPOCH[13] - STEP[60]
# Generator_loss:3.1925
# L1_loss:0.1933
# Discriminator_loss:0.6242
#
# EPOCH[13] - STEP[80]
# Generator_loss:1.4951
# L1_loss:0.1555
# Discriminator_loss:0.6225
#
# EPOCH[13] - STEP[100]
# Generator_loss:0.5182
# L1_loss:0.1698
# Discriminator_loss:1.2970
#
# EPOCH[13] - STEP[120]
# Generator_loss:0.5421
# L1_loss:0.1476
# Discriminator_loss:1.2940
#
# EPOCH[13] - STEP[140]
# Generator_loss:2.3607
# L1_loss:0.1457
# Discriminator_loss:1.2643
#
# EPOCH[13] - STEP[160]
# Generator_loss:2.6262
# L1_loss:0.1628
# Discriminator_loss:0.9849
#
# EPOCH[13] - STEP[180]
# Generator_loss:3.0276
# L1_loss:0.1770
# Discriminator_loss:0.8291
#
# EPOCH[13] - STEP[200]
# Generator_loss:1.3142
# L1_loss:0.1638
# Discriminator_loss:0.4734
#
# EPOCH[13] - STEP[220]
# Generator_loss:1.7562
# L1_loss:0.1629
# Discriminator_loss:0.7239
#
# EPOCH[13] - STEP[240]
# Generator_loss:1.3744
# L1_loss:0.1714
# Discriminator_loss:0.6981
#
# EPOCH[14] - STEP[20]
# Generator_loss:1.5905
# L1_loss:0.1365
# Discriminator_loss:1.0525
#
# EPOCH[14] - STEP[40]
# Generator_loss:1.1888
# L1_loss:0.1752
# Discriminator_loss:0.5327
#
# EPOCH[14] - STEP[60]
# Generator_loss:2.7821
# L1_loss:0.2157
# Discriminator_loss:0.5850
#
# EPOCH[14] - STEP[80]
# Generator_loss:1.4310
# L1_loss:0.1822
# Discriminator_loss:0.4870
#
# EPOCH[14] - STEP[100]
# Generator_loss:1.5622
# L1_loss:0.2456
# Discriminator_loss:0.4016
#
# EPOCH[14] - STEP[120]
# Generator_loss:2.5049
# L1_loss:0.1549
# Discriminator_loss:0.4292
#
# EPOCH[14] - STEP[140]
# Generator_loss:0.9433
# L1_loss:0.1593
# Discriminator_loss:0.6226
#
# EPOCH[14] - STEP[160]
# Generator_loss:0.9534
# L1_loss:0.1645
# Discriminator_loss:0.8213
#
# EPOCH[14] - STEP[180]
# Generator_loss:2.5776
# L1_loss:0.2298
# Discriminator_loss:0.1615
#
# EPOCH[14] - STEP[200]
# Generator_loss:1.8112
# L1_loss:0.1718
# Discriminator_loss:0.2890
#
# EPOCH[14] - STEP[220]
# Generator_loss:0.6255
# L1_loss:0.1559
# Discriminator_loss:1.0738
#
# EPOCH[14] - STEP[240]
# Generator_loss:1.4700
# L1_loss:0.1741
# Discriminator_loss:0.3639
# EPOCH[15] - STEP[20]
# Generator_loss:1.8983
# L1_loss:0.2119
# Discriminator_loss:0.3264
#
# EPOCH[15] - STEP[40]
# Generator_loss:1.9475
# L1_loss:0.1833
# Discriminator_loss:0.9426
#
# EPOCH[15] - STEP[60]
# Generator_loss:2.9338
# L1_loss:0.1624
# Discriminator_loss:0.8176
#
# EPOCH[15] - STEP[80]
# Generator_loss:0.8662
# L1_loss:0.1569
# Discriminator_loss:1.0356
#
# EPOCH[15] - STEP[100]
# Generator_loss:1.9890
# L1_loss:0.1449
# Discriminator_loss:0.4409
#
# EPOCH[15] - STEP[120]
# Generator_loss:1.1428
# L1_loss:0.1783
# Discriminator_loss:0.6868
#
# EPOCH[15] - STEP[140]
# Generator_loss:2.8086
# L1_loss:0.2173
# Discriminator_loss:0.1539
#
# EPOCH[15] - STEP[160]
# Generator_loss:2.4702
# L1_loss:0.1754
# Discriminator_loss:0.5038
#
# EPOCH[15] - STEP[180]
# Generator_loss:2.1952
# L1_loss:0.1610
# Discriminator_loss:0.6516
#
# EPOCH[15] - STEP[200]
# Generator_loss:1.3004
# L1_loss:0.1593
# Discriminator_loss:0.5949
#
# EPOCH[15] - STEP[220]
# Generator_loss:1.4743
# L1_loss:0.1965
# Discriminator_loss:0.5560
#
# EPOCH[15] - STEP[240]
# Generator_loss:0.9285
# L1_loss:0.1632
# Discriminator_loss:0.7064
#
# EPOCH[16] - STEP[20]
# Generator_loss:2.6001
# L1_loss:0.1799
# Discriminator_loss:0.6662
#
# EPOCH[16] - STEP[40]
# Generator_loss:2.3415
# L1_loss:0.1687
# Discriminator_loss:0.3220
#
# EPOCH[16] - STEP[60]
# Generator_loss:2.7793
# L1_loss:0.2016
# Discriminator_loss:0.3525
#
# EPOCH[16] - STEP[80]
# Generator_loss:0.5006
# L1_loss:0.1809
# Discriminator_loss:1.4819
#
# EPOCH[16] - STEP[100]
# Generator_loss:1.9707
# L1_loss:0.1416
# Discriminator_loss:2.1919
#
# EPOCH[16] - STEP[120]
# Generator_loss:0.5551
# L1_loss:0.1745
# Discriminator_loss:1.3082
#
# EPOCH[16] - STEP[140]
# Generator_loss:0.3078
# L1_loss:0.1480
# Discriminator_loss:1.6937
#
# EPOCH[16] - STEP[160]
# Generator_loss:2.1979
# L1_loss:0.1963
# Discriminator_loss:0.5653
#
# EPOCH[16] - STEP[180]
# Generator_loss:1.7275
# L1_loss:0.1488
# Discriminator_loss:0.5906
#
# EPOCH[16] - STEP[200]
# Generator_loss:1.0953
# L1_loss:0.1965
# Discriminator_loss:0.6757
#
# EPOCH[16] - STEP[220]
# Generator_loss:1.0924
# L1_loss:0.1603
# Discriminator_loss:0.7686
#
# EPOCH[16] - STEP[240]
# Generator_loss:1.9153
# L1_loss:0.1842
# Discriminator_loss:0.3982
#
# EPOCH[17] - STEP[20]
# Generator_loss:3.3611
# L1_loss:0.1864
# Discriminator_loss:0.1085
#
# EPOCH[17] - STEP[40]
# Generator_loss:1.1683
# L1_loss:0.1934
# Discriminator_loss:0.5373
#
# EPOCH[17] - STEP[60]
# Generator_loss:0.3966
# L1_loss:0.1633
# Discriminator_loss:1.7005
#
# EPOCH[17] - STEP[80]
# Generator_loss:0.9671
# L1_loss:0.1475
# Discriminator_loss:0.8508
#
# EPOCH[17] - STEP[100]
# Generator_loss:2.5820
# L1_loss:0.1608
# Discriminator_loss:1.1860
#
# EPOCH[17] - STEP[120]
# Generator_loss:1.8505
# L1_loss:0.1366
# Discriminator_loss:0.9769
#
# EPOCH[17] - STEP[140]
# Generator_loss:1.9786
# L1_loss:0.1737
# Discriminator_loss:0.2744
#
# EPOCH[17] - STEP[160]
# Generator_loss:1.6422
# L1_loss:0.1647
# Discriminator_loss:0.5754
#
# EPOCH[17] - STEP[180]
# Generator_loss:2.0264
# L1_loss:0.1511
# Discriminator_loss:0.2974
#
# EPOCH[17] - STEP[200]
# Generator_loss:1.2535
# L1_loss:0.1585
# Discriminator_loss:0.8992
#
# EPOCH[17] - STEP[220]
# Generator_loss:0.6584
# L1_loss:0.1436
# Discriminator_loss:0.8608
#
# EPOCH[17] - STEP[240]
# Generator_loss:1.0560
# L1_loss:0.1851
# Discriminator_loss:1.4962
#
# EPOCH[18] - STEP[20]
# Generator_loss:1.6327
# L1_loss:0.1622
# Discriminator_loss:0.4959
#
# EPOCH[18] - STEP[40]
# Generator_loss:2.0207
# L1_loss:0.1404
# Discriminator_loss:0.2773
#
# EPOCH[18] - STEP[60]
# Generator_loss:2.2232
# L1_loss:0.1744
# Discriminator_loss:0.7413
#
# EPOCH[18] - STEP[80]
# Generator_loss:1.2658
# L1_loss:0.1641
# Discriminator_loss:1.2039
#
# EPOCH[18] - STEP[100]
# Generator_loss:1.3315
# L1_loss:0.1797
# Discriminator_loss:0.4950
#
# EPOCH[18] - STEP[120]
# Generator_loss:3.0738
# L1_loss:0.2021
# Discriminator_loss:0.1739
#
# EPOCH[18] - STEP[140]
# Generator_loss:2.0819
# L1_loss:0.1617
# Discriminator_loss:0.8349
#
# EPOCH[18] - STEP[160]
# Generator_loss:0.5600
# L1_loss:0.1476
# Discriminator_loss:1.0690
#
# EPOCH[18] - STEP[180]
# Generator_loss:1.7307
# L1_loss:0.1758
# Discriminator_loss:0.2653
#
# EPOCH[18] - STEP[200]
# Generator_loss:2.4441
# L1_loss:0.1710
# Discriminator_loss:0.2447
#
# EPOCH[18] - STEP[220]
# Generator_loss:1.0165
# L1_loss:0.1695
# Discriminator_loss:0.5634
#
# EPOCH[18] - STEP[240]
# Generator_loss:1.5132
# L1_loss:0.1291
# Discriminator_loss:0.4793
#
# EPOCH[19] - STEP[20]
# Generator_loss:1.8122
# L1_loss:0.1787
# Discriminator_loss:0.5048
#
# EPOCH[19] - STEP[40]
# Generator_loss:2.3163
# L1_loss:0.1906
# Discriminator_loss:0.2073
#
# EPOCH[19] - STEP[60]
# Generator_loss:2.5675
# L1_loss:0.1865
# Discriminator_loss:0.5081
#
# EPOCH[19] - STEP[80]
# Generator_loss:1.0477
# L1_loss:0.2022
# Discriminator_loss:0.7117
#
# EPOCH[19] - STEP[100]
# Generator_loss:0.4563
# L1_loss:0.1609
# Discriminator_loss:1.3880
#
# EPOCH[19] - STEP[120]
# Generator_loss:3.1389
# L1_loss:0.1516
# Discriminator_loss:0.5011
#
# EPOCH[19] - STEP[140]
# Generator_loss:3.2303
# L1_loss:0.1788
# Discriminator_loss:0.0902
#
# EPOCH[19] - STEP[160]
# Generator_loss:3.1016
# L1_loss:0.1352
# Discriminator_loss:0.6496
# EPOCH[19] - STEP[180]
# Generator_loss:1.3915
# L1_loss:0.1580
# Discriminator_loss:0.4407
#
# EPOCH[19] - STEP[200]
# Generator_loss:1.5144
# L1_loss:0.1373
# Discriminator_loss:0.5541
#
# EPOCH[19] - STEP[220]
# Generator_loss:2.5779
# L1_loss:0.1920
# Discriminator_loss:0.1797
#
# EPOCH[19] - STEP[240]
# Generator_loss:1.7911
# L1_loss:0.1384
# Discriminator_loss:0.4584
#
# EPOCH[20] - STEP[20]
# Generator_loss:1.9136
# L1_loss:0.1484
# Discriminator_loss:0.3446
#
# EPOCH[20] - STEP[40]
# Generator_loss:1.4836
# L1_loss:0.1688
# Discriminator_loss:0.4908
#
# EPOCH[20] - STEP[60]
# Generator_loss:2.2015
# L1_loss:0.1911
# Discriminator_loss:0.2746
#
# EPOCH[20] - STEP[80]
# Generator_loss:2.4540
# L1_loss:0.1412
# Discriminator_loss:0.6084
#
# EPOCH[20] - STEP[100]
# Generator_loss:2.3554
# L1_loss:0.2052
# Discriminator_loss:0.2036
#
# EPOCH[20] - STEP[120]
# Generator_loss:1.8515
# L1_loss:0.1928
# Discriminator_loss:0.3634
#
# EPOCH[20] - STEP[140]
# Generator_loss:1.4342
# L1_loss:0.1467
# Discriminator_loss:0.5004
#
# EPOCH[20] - STEP[160]
# Generator_loss:1.0729
# L1_loss:0.1547
# Discriminator_loss:0.8826
#
# EPOCH[20] - STEP[180]
# Generator_loss:0.4191
# L1_loss:0.1765
# Discriminator_loss:1.5041
#
# EPOCH[20] - STEP[200]
# Generator_loss:2.6986
# L1_loss:0.1510
# Discriminator_loss:0.2324
#
# EPOCH[20] - STEP[220]
# Generator_loss:1.3615
# L1_loss:0.1495
# Discriminator_loss:0.6581
#
# EPOCH[20] - STEP[240]
# Generator_loss:0.5552
# L1_loss:0.1862
# Discriminator_loss:1.1443
#
# EPOCH[21] - STEP[20]
# Generator_loss:4.2216
# L1_loss:0.1551
# Discriminator_loss:0.6882
#
# EPOCH[21] - STEP[40]
# Generator_loss:2.1436
# L1_loss:0.1629
# Discriminator_loss:0.4045
#
# EPOCH[21] - STEP[60]
# Generator_loss:0.4264
# L1_loss:0.1582
# Discriminator_loss:1.4355
#
# EPOCH[21] - STEP[80]
# Generator_loss:2.7443
# L1_loss:0.1297
# Discriminator_loss:0.4132
#
# EPOCH[21] - STEP[100]
# Generator_loss:0.6149
# L1_loss:0.2232
# Discriminator_loss:1.2815
#
# EPOCH[21] - STEP[120]
# Generator_loss:1.8432
# L1_loss:0.1659
# Discriminator_loss:0.2996
#
# EPOCH[21] - STEP[140]
# Generator_loss:4.1544
# L1_loss:0.1460
# Discriminator_loss:0.9553
#
# EPOCH[21] - STEP[160]
# Generator_loss:3.3209
# L1_loss:0.1357
# Discriminator_loss:1.1529
#
# EPOCH[21] - STEP[180]
# Generator_loss:2.7921
# L1_loss:0.1981
# Discriminator_loss:0.1232
#
# EPOCH[21] - STEP[200]
# Generator_loss:0.9199
# L1_loss:0.1555
# Discriminator_loss:1.0095
#
# EPOCH[21] - STEP[220]
# Generator_loss:1.7704
# L1_loss:0.1675
# Discriminator_loss:0.7286
#
# EPOCH[21] - STEP[240]
# Generator_loss:2.2583
# L1_loss:0.1978
# Discriminator_loss:0.4092
#
# EPOCH[22] - STEP[20]
# Generator_loss:1.1258
# L1_loss:0.1599
# Discriminator_loss:0.7157
#
# EPOCH[22] - STEP[40]
# Generator_loss:1.7380
# L1_loss:0.1414
# Discriminator_loss:0.6839
#
# EPOCH[22] - STEP[60]
# Generator_loss:1.2396
# L1_loss:0.1583
# Discriminator_loss:0.5659
#
# EPOCH[22] - STEP[80]
# Generator_loss:2.6501
# L1_loss:0.1590
# Discriminator_loss:0.2738
#
# EPOCH[22] - STEP[100]
# Generator_loss:2.3294
# L1_loss:0.1424
# Discriminator_loss:0.8476
#
# EPOCH[22] - STEP[120]
# Generator_loss:1.7495
# L1_loss:0.1387
# Discriminator_loss:0.5672
#
# EPOCH[22] - STEP[140]
# Generator_loss:1.9006
# L1_loss:0.1605
# Discriminator_loss:0.7021
#
# EPOCH[22] - STEP[160]
# Generator_loss:1.1875
# L1_loss:0.1774
# Discriminator_loss:0.7305
#
# EPOCH[22] - STEP[180]
# Generator_loss:2.7670
# L1_loss:0.1641
# Discriminator_loss:0.2951
#
# EPOCH[22] - STEP[200]
# Generator_loss:2.2478
# L1_loss:0.1892
# Discriminator_loss:0.3130
#
# EPOCH[22] - STEP[220]
# Generator_loss:2.3225
# L1_loss:0.1611
# Discriminator_loss:0.8352
#
# EPOCH[22] - STEP[240]
# Generator_loss:3.3323
# L1_loss:0.1588
# Discriminator_loss:0.2684
#
# EPOCH[23] - STEP[20]
# Generator_loss:2.0352
# L1_loss:0.1537
# Discriminator_loss:1.3590
#
# EPOCH[23] - STEP[40]
# Generator_loss:3.9107
# L1_loss:0.1694
# Discriminator_loss:0.7767
#
# EPOCH[23] - STEP[60]
# Generator_loss:2.5690
# L1_loss:0.1784
# Discriminator_loss:0.2489
#
# EPOCH[23] - STEP[80]
# Generator_loss:2.7243
# L1_loss:0.1865
# Discriminator_loss:0.2196
#
# EPOCH[23] - STEP[100]
# Generator_loss:2.9748
# L1_loss:0.1491
# Discriminator_loss:0.6036
#
# EPOCH[23] - STEP[120]
# Generator_loss:1.9997
# L1_loss:0.2136
# Discriminator_loss:0.2444
#
# EPOCH[23] - STEP[140]
# Generator_loss:2.6757
# L1_loss:0.1439
# Discriminator_loss:0.3427
#
# EPOCH[23] - STEP[160]
# Generator_loss:1.9327
# L1_loss:0.1759
# Discriminator_loss:0.6851
#
# EPOCH[23] - STEP[180]
# Generator_loss:2.5819
# L1_loss:0.1571
# Discriminator_loss:0.3976
#
# EPOCH[23] - STEP[200]
# Generator_loss:1.8168
# L1_loss:0.1439
# Discriminator_loss:1.0654
#
# EPOCH[23] - STEP[220]
# Generator_loss:3.7981
# L1_loss:0.1591
# Discriminator_loss:0.2499
#
# EPOCH[23] - STEP[240]
# Generator_loss:0.7534
# L1_loss:0.1622
# Discriminator_loss:1.0581
#
# EPOCH[24] - STEP[20]
# Generator_loss:1.5369
# L1_loss:0.1583
# Discriminator_loss:0.3868
#
# EPOCH[24] - STEP[40]
# Generator_loss:1.5138
# L1_loss:0.1425
# Discriminator_loss:0.7229
#
# EPOCH[24] - STEP[60]
# Generator_loss:3.5851
# L1_loss:0.1811
# Discriminator_loss:0.2642
#
# EPOCH[24] - STEP[80]
# Generator_loss:3.1015
# L1_loss:0.1571
# Discriminator_loss:0.3708
# EPOCH[24] - STEP[100]
# Generator_loss:1.0393
# L1_loss:0.1468
# Discriminator_loss:0.6565
#
# EPOCH[24] - STEP[120]
# Generator_loss:1.3021
# L1_loss:0.1208
# Discriminator_loss:0.9582
#
# EPOCH[24] - STEP[140]
# Generator_loss:3.3717
# L1_loss:0.1454
# Discriminator_loss:0.4722
#
# EPOCH[24] - STEP[160]
# Generator_loss:2.2382
# L1_loss:0.1374
# Discriminator_loss:0.5957
#
# EPOCH[24] - STEP[180]
# Generator_loss:1.3209
# L1_loss:0.1845
# Discriminator_loss:0.6537
#
# EPOCH[24] - STEP[200]
# Generator_loss:3.4063
# L1_loss:0.1971
# Discriminator_loss:0.5012
#
# EPOCH[24] - STEP[220]
# Generator_loss:3.1413
# L1_loss:0.1780
# Discriminator_loss:0.2580
#
# EPOCH[24] - STEP[240]
# Generator_loss:1.1386
# L1_loss:0.1375
# Discriminator_loss:0.7220
#
# EPOCH[25] - STEP[20]
# Generator_loss:0.7832
# L1_loss:0.1651
# Discriminator_loss:1.1075
#
# EPOCH[25] - STEP[40]
# Generator_loss:1.9366
# L1_loss:0.1644
# Discriminator_loss:0.4119
#
# EPOCH[25] - STEP[60]
# Generator_loss:2.7465
# L1_loss:0.1432
# Discriminator_loss:0.6170
#
# EPOCH[25] - STEP[80]
# Generator_loss:0.5767
# L1_loss:0.1254
# Discriminator_loss:1.1028
#
# EPOCH[25] - STEP[100]
# Generator_loss:2.8111
# L1_loss:0.1341
# Discriminator_loss:0.8633
#
# EPOCH[25] - STEP[120]
# Generator_loss:3.0957
# L1_loss:0.1705
# Discriminator_loss:0.4999
#
# EPOCH[25] - STEP[140]
# Generator_loss:2.4068
# L1_loss:0.1191
# Discriminator_loss:1.0875
#
# EPOCH[25] - STEP[160]
# Generator_loss:3.1670
# L1_loss:0.1560
# Discriminator_loss:0.3936
#
# EPOCH[25] - STEP[180]
# Generator_loss:3.5798
# L1_loss:0.1788
# Discriminator_loss:0.5719
#
# EPOCH[25] - STEP[200]
# Generator_loss:3.8207
# L1_loss:0.1277
# Discriminator_loss:2.2083
#
# EPOCH[25] - STEP[220]
# Generator_loss:1.9167
# L1_loss:0.1315
# Discriminator_loss:0.4572
#
# EPOCH[25] - STEP[240]
# Generator_loss:1.9794
# L1_loss:0.1309
# Discriminator_loss:1.0117
#
# EPOCH[26] - STEP[20]
# Generator_loss:3.2487
# L1_loss:0.2192
# Discriminator_loss:0.0813
#
# EPOCH[26] - STEP[40]
# Generator_loss:2.4525
# L1_loss:0.1584
# Discriminator_loss:0.8863
#
# EPOCH[26] - STEP[60]
# Generator_loss:1.7830
# L1_loss:0.1630
# Discriminator_loss:0.4898
#
# EPOCH[26] - STEP[80]
# Generator_loss:1.0584
# L1_loss:0.1718
# Discriminator_loss:0.6492
#
# EPOCH[26] - STEP[100]
# Generator_loss:0.6669
# L1_loss:0.1663
# Discriminator_loss:1.2485
#
# EPOCH[26] - STEP[120]
# Generator_loss:1.2268
# L1_loss:0.1600
# Discriminator_loss:0.6365
#
# EPOCH[26] - STEP[140]
# Generator_loss:3.2228
# L1_loss:0.1557
# Discriminator_loss:1.1826
#
# EPOCH[26] - STEP[160]
# Generator_loss:2.5412
# L1_loss:0.1628
# Discriminator_loss:0.2853
#
# EPOCH[26] - STEP[180]
# Generator_loss:3.1839
# L1_loss:0.2078
# Discriminator_loss:0.1058
#
# EPOCH[26] - STEP[200]
# Generator_loss:1.1627
# L1_loss:0.1674
# Discriminator_loss:0.5973
#
# EPOCH[26] - STEP[220]
# Generator_loss:4.1764
# L1_loss:0.1616
# Discriminator_loss:0.3949
#
# EPOCH[26] - STEP[240]
# Generator_loss:1.2512
# L1_loss:0.1258
# Discriminator_loss:0.9109
#
# EPOCH[27] - STEP[20]
# Generator_loss:1.7958
# L1_loss:0.1497
# Discriminator_loss:0.5098
#
# EPOCH[27] - STEP[40]
# Generator_loss:2.1551
# L1_loss:0.1761
# Discriminator_loss:0.2260
#
# EPOCH[27] - STEP[60]
# Generator_loss:2.5096
# L1_loss:0.1254
# Discriminator_loss:1.0787
#
# EPOCH[27] - STEP[80]
# Generator_loss:1.3015
# L1_loss:0.1824
# Discriminator_loss:0.5454
#
# EPOCH[27] - STEP[100]
# Generator_loss:2.0884
# L1_loss:0.1697
# Discriminator_loss:0.3319
#
# EPOCH[27] - STEP[120]
# Generator_loss:1.8108
# L1_loss:0.1357
# Discriminator_loss:0.7808
#
# EPOCH[27] - STEP[140]
# Generator_loss:3.4888
# L1_loss:0.1696
# Discriminator_loss:0.4615
#
# EPOCH[27] - STEP[160]
# Generator_loss:3.9486
# L1_loss:0.1763
# Discriminator_loss:0.3653
#
# EPOCH[27] - STEP[180]
# Generator_loss:2.7579
# L1_loss:0.1356
# Discriminator_loss:1.1772
#
# EPOCH[27] - STEP[200]
# Generator_loss:1.9496
# L1_loss:0.1338
# Discriminator_loss:0.6438
#
# EPOCH[27] - STEP[220]
# Generator_loss:1.7337
# L1_loss:0.1777
# Discriminator_loss:0.3506
#
# EPOCH[27] - STEP[240]
# Generator_loss:2.0411
# L1_loss:0.1547
# Discriminator_loss:0.2568
#
# EPOCH[28] - STEP[20]
# Generator_loss:2.5414
# L1_loss:0.1778
# Discriminator_loss:0.4159
#
# EPOCH[28] - STEP[40]
# Generator_loss:2.3743
# L1_loss:0.1626
# Discriminator_loss:0.8856
#
# EPOCH[28] - STEP[60]
# Generator_loss:1.6298
# L1_loss:0.1575
# Discriminator_loss:0.3899
#
# EPOCH[28] - STEP[80]
# Generator_loss:3.3687
# L1_loss:0.1674
# Discriminator_loss:0.9096
#
# EPOCH[28] - STEP[100]
# Generator_loss:3.9575
# L1_loss:0.1514
# Discriminator_loss:0.7586
#
# EPOCH[28] - STEP[120]
# Generator_loss:2.4583
# L1_loss:0.1597
# Discriminator_loss:0.8914
#
# EPOCH[28] - STEP[140]
# Generator_loss:1.8221
# L1_loss:0.1665
# Discriminator_loss:0.4849
#
# EPOCH[28] - STEP[160]
# Generator_loss:0.8755
# L1_loss:0.1407
# Discriminator_loss:0.7736
#
# EPOCH[28] - STEP[180]
# Generator_loss:0.2894
# L1_loss:0.1389
# Discriminator_loss:1.9168
#
# EPOCH[28] - STEP[200]
# Generator_loss:3.0556
# L1_loss:0.1396
# Discriminator_loss:1.2394
#
# EPOCH[28] - STEP[220]
# Generator_loss:0.6849
# L1_loss:0.1846
# Discriminator_loss:0.9490
#
# EPOCH[28] - STEP[240]
# Generator_loss:1.1382
# L1_loss:0.1802
# Discriminator_loss:0.6189
# EPOCH[29] - STEP[20]
# Generator_loss:0.9410
# L1_loss:0.1501
# Discriminator_loss:0.6413
#
# EPOCH[29] - STEP[40]
# Generator_loss:1.2073
# L1_loss:0.1564
# Discriminator_loss:0.6247
#
# EPOCH[29] - STEP[60]
# Generator_loss:3.9745
# L1_loss:0.1441
# Discriminator_loss:1.1681
#
# EPOCH[29] - STEP[80]
# Generator_loss:0.4499
# L1_loss:0.1527
# Discriminator_loss:1.3901
#
# EPOCH[29] - STEP[100]
# Generator_loss:2.8777
# L1_loss:0.1567
# Discriminator_loss:1.0901
#
# EPOCH[29] - STEP[120]
# Generator_loss:2.5025
# L1_loss:0.1169
# Discriminator_loss:0.4166
#
# EPOCH[29] - STEP[140]
# Generator_loss:0.9710
# L1_loss:0.1362
# Discriminator_loss:0.8409
#
# EPOCH[29] - STEP[160]
# Generator_loss:1.9977
# L1_loss:0.1390
# Discriminator_loss:0.2952
#
# EPOCH[29] - STEP[180]
# Generator_loss:0.7450
# L1_loss:0.1393
# Discriminator_loss:0.9215
#
# EPOCH[29] - STEP[200]
# Generator_loss:3.3138
# L1_loss:0.1777
# Discriminator_loss:0.0945
#
# EPOCH[29] - STEP[220]
# Generator_loss:4.5103
# L1_loss:0.1527
# Discriminator_loss:0.4721
#
# EPOCH[29] - STEP[240]
# Generator_loss:3.0789
# L1_loss:0.1622
# Discriminator_loss:0.5434
#
# EPOCH[30] - STEP[20]
# Generator_loss:4.2553
# L1_loss:0.1490
# Discriminator_loss:0.7384
#
# EPOCH[30] - STEP[40]
# Generator_loss:4.7018
# L1_loss:0.1983
# Discriminator_loss:0.1998
#
# EPOCH[30] - STEP[60]
# Generator_loss:2.9897
# L1_loss:0.1364
# Discriminator_loss:0.2048
#
# EPOCH[30] - STEP[80]
# Generator_loss:0.3616
# L1_loss:0.1537
# Discriminator_loss:1.5080
#
# EPOCH[30] - STEP[100]
# Generator_loss:3.2268
# L1_loss:0.1533
# Discriminator_loss:0.6728
#
# EPOCH[30] - STEP[120]
# Generator_loss:3.7234
# L1_loss:0.1606
# Discriminator_loss:1.1662
#
# EPOCH[30] - STEP[140]
# Generator_loss:1.5968
# L1_loss:0.1509
# Discriminator_loss:0.3971
#
# EPOCH[30] - STEP[160]
# Generator_loss:0.9832
# L1_loss:0.1635
# Discriminator_loss:0.6807
#
# EPOCH[30] - STEP[180]
# Generator_loss:3.2107
# L1_loss:0.1323
# Discriminator_loss:0.2793
#
# EPOCH[30] - STEP[200]
# Generator_loss:4.5471
# L1_loss:0.1681
# Discriminator_loss:0.6443
#
# EPOCH[30] - STEP[220]
# Generator_loss:2.5631
# L1_loss:0.1555
# Discriminator_loss:0.1663
#
# EPOCH[30] - STEP[240]
# Generator_loss:2.3374
# L1_loss:0.1426
# Discriminator_loss:0.5263

# %%
#채색하기(시각화)
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
sketch, original = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))

plt.subplot(1,3,1); plt.imshow(denormalize(original)); plt.title('sketch', fontsize=20)
plt.subplot(1,3,2); plt.imshow(pred[0]); plt.title('generated photo', fontsize=20)
plt.subplot(1,3,3); plt.imshow(denormalize(sketch)); plt.title('original photo', fontsize=20)
# Out:
# Text(0.5, 1.0, 'original photo')
